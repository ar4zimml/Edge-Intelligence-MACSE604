# %%
# !pip install kaggle #installing Kaggle

# %%
# !pip install opendatasets #Installing opendatasets

# %%
#Loading dataset from URL
import opendatasets as od
dataset_url = 'https://www.kaggle.com/datasets/likhon148/animal-data'
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: Ahamed Razi C 25MML0058
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/likhon148/animal-data
# ...
# 100%|██████████| 36.3M/36.3M [00:00<00:00, 1.46GB/s]

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

# path to your image directory
dataset_path = './animal-data/animal_data/Cat'

# List the contents of the directory
print(os.listdir(dataset_path))

# Load a single image
image_name = 'Cat_9_3.jpg'
img = Image.open(os.path.join(dataset_path, image_name))

# Display the image
plt.imshow(img)
plt.axis('off') # Hide axis
plt.show()
# Out:
# ['Cat_28_2.jpg', 'Cat_15_4.jpg', 'Cat_21_3.jpg', 'Cat_3.jpg', 'Cat_14_3.jpg', 'Cat_18_2.jpg', 'Cat_11_3.jpg', 'Cat_2.jpeg', 'Cat_18_3.jpg', 'Cat_15.jpg', 'Cat_8_2.jpg', 'Cat_26_2.jpg', 'Cat_17.jpeg', 'Cat_10_1.jpg', 'Cat_1_1.jpg', 'Cat_7.jpeg', 'Cat_5_2.jpg', 'Cat_6_2.jpg', 'Cat_29_1.jpg', 'Cat_16_3.jpg', 'Cat_23_2.jpg', 'Cat_27_3.jpg', 'Cat_1_3.jpg', 'Cat_7_1.jpg', 'Cat_24.jpeg', 'Cat_2_1.jpg', 'Cat_26_3.jpg', 'Cat_26.jpeg', 'Cat_8_4.jpg', 'Cat_1_2.jpg', 'Cat_24_1.jpg', 'Cat_10.jpg', 'Cat_25_2.jpg', 'Cat_24_2.jpg', 'Cat_3_1.jpg', 'Cat_7_2.jpg', 'Cat_3_3.jpg', 'Cat_16_2.jpg', 'Cat_29_2.jpg', 'Cat_13_1.jpg', 'Cat_13.jpeg', 'Cat_29.jpeg', 'Cat_9_2.jpg', 'Cat_12_3.jpg', 'Cat_15_1.jpg', 'Cat_11_2.jpg', 'Cat_18_1.jpg', 'Cat_8_1.jpg', 'Cat_4_1.jpg', 'Cat_10_4.jpg', 'Cat_6_3.jpg', 'Cat_12.jpg', 'Cat_23.jpeg', 'Cat_22.jpg', 'Cat_25.jpg', 'Cat_5_3.jpg', 'Cat_2_2.jpg', 'Cat_16_1.jpg', 'Cat_30_1.jpg', 'Cat_11_4.jpg', 'Cat_15_3.jpg', 'Cat_7_4.jpg', 'Cat_6_1.jpg', 'Cat_21.jpeg', 'Cat_28.jpeg', 'C
# ...

# %%
# Check the shape of the image

# PIL returns (width, height)
print(f"Image size (PIL format: width, height): {img.size}")


width, height = img.size
print(f"Width: {width}, Height: {height}")

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Image size (PIL format: width, height): (224, 224)
# Width: 224, Height: 224
